# %% [markdown]
# # Необходимые ссылки:

# %% [markdown]
# - https://gitlab.com/Nanopro/TecWrap - ссылка на свежую версию моей библиотеки TecWrap
# - https://github.com/Nanopro/tecwrap_guide - ссылка на эту демонстрацию со всеми файлами, которые могут понадобиться при установке

# %% [markdown]
# # 1. Установка

# %% [markdown]
# Предварительные настройки:
# - Добавить в \$PATH путь до ESI\2014.0\UTILS\bin (если планируется автоматическая конвертация .dtf файлов);
# - Создать переменную $TEC360_PATH содержащую путь до директории инсталяции TecPlot360/bin
# - переместить файл startTecUtilServer.mcr (см. папку install) в TecPlot360/bin

# %% [markdown]
# Оффлайн установка:
# 1. скачать flatbuffers-2015.12.22.1-py2.py3-none-any (см. папку install), перейти в папку с этим файлом, выполнить комманду в bash/cmd/Anaconda promt "pip install flatbuffers-2015.12.22.1-py2.py3-none-any"
# 2. перейти в директорию установки Tecplot 360 EX 2018 R1/pytecplot, выполнить в bash/cmd/Anaconda promt "pip install ."
# 3. скачать tecwrap.py в дирректорию, в которой находятся ваши .py/.ipynb файлы, с которыми ведете работу

# %% [markdown]
# Онлайн установка:
# 1. выполнить pip install pytecplot
# 2. скачать tecwrap.py в дирректорию, в которой находятся ваши .py/.ipynb файлы, с которыми ведете работу

# %% [markdown]
# # 2. Использование библиотеки TecWrap

# %% [markdown]
# Импорт необходимых библиотек:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tecwrap import TecWrapper, TecSession
import numpy as np

# %% [markdown]
# Опционально для создание графиков:

# %%
import plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
from matplotlib.mlab import griddata

# %matplotlib inline
py.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Устанавливаем соединение с TecPlot, в качестве аргумента указываем директорию с файлами которые будем обрабатывать (опционально):

# %%
wrap = TecWrapper(r'C:\Users\Nanopro\tecwrap_guide')
# Out:
# Connecting to Tecplot 360 TecUtil Server on:
#     tcp://localhost:7600
# Connection established.

# %% [markdown]
# Произойдет запуск Tecplot и подключение скрипта к нему. В случае успеха появится сообщение Connection established.

# %% [markdown]
# Для того чтобы открыть файл и производить в нём какие либо действия, используется протокол менеджера контекста:

# %%
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.dtf') as ses:
    pass
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.dtf
# 0

# %% [markdown]
# В окне TecPlot произойдет открытие файла, в котором уже будут произведены все указанные манипуляции.

# %% [markdown]
# <img src="images/tube.jpg">

# %% [markdown]
# В качестве аргумента принимаются:
# - путь до файла расширения .dtf, .tec относительно рабочей директории, которая была указана в аргументах TecWrapper
# - полный путь до файла

# %% [markdown]
# ## Реализованные функции:

# %% [markdown]
# Объемный срез плоскость через все активные зоны:

# %%
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.dtf') as ses:
    X,Y, W, P_tot = ses.volume_slices(
        origins = [
        (0,0,z) for z in [0, 0.33 -1e-14, 0.66-1e-14, 1-1e-14]
    ], 
        normal = (0,0,1),
        values = ('X', 'Y', 'W', 'P_tot'),
    )
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.dtf
# 0

# %% [markdown]
# Пример окна TecPlotпосле выполнения команды выше:

# %% [markdown]
# <img src="images/zslices.jpg">

# %% [markdown]
# # Warning!

# %% [markdown]
# По неизвестной никому причине, слайсы, плоскости которых совпадают с линиями сетки ведут себя непредсказуемо! Поэтому к координате каждого сечения лучше прибавлять или отнимать очень маленькое число (например 1e-14, меньше не работает).

# %%
print(type(W), W.shape)
# Out:
# <class 'numpy.ndarray'> (4, 500)

# %%
trace = go.Scatter3d(x = X[2], y = Y[2], z = W[2], mode = 'markers')
py.offline.iplot([trace])
# Out:
# <div id="96388201-33fb-49e1-8557-4315224ea0d3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
516305573, 0.002209945287968411, 0.002113299482821529, 0.00199386667252022, 0.0018452661092816084, 0.0016599740469460506, 0.0014289417084251534, 0.0011409811493439483, 0.0024904867363354094, 0.0024290698489952195, 0.00235906873107085, 0.0022759874864311993, 0.0021747986265552317, 0.0020497516067926546, 0.0018941657378748146, 0.0017001636029315874, 0.0014582710666349646, 0.0011567742699722507, 0.002490486736335409, 0.00242906984899522, 0.00235906873107085, 0.0022759874864311993, 0.0021747986265552312, 0.0020497516067926546, 0.0018941657378748135, 0.0017001636029315864, 0.0014582710666349648, 0.0011567742699722505, 0.0024148142106 ...

# %%
xi, yi = np.meshgrid(
    np.linspace(X[2].min(), X[2].max(), 1000),
    np.linspace(Y[2].min(), Y[2].max(), 1000),             
)
zi = griddata(X[2], Y[2], W[2],xi, yi, interp='linear')
# Out:
# C:\Users\ewe\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
#
# The griddata function was deprecated in version 2.2.

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(xi, yi, zi, rstride=10, cstride=10)

plt.show()

# %%
plt.figure(figsize = (10,10))
plt.imshow(zi, cmap = 'gist_rainbow')
plt.tick_params(labelsize = 18)
plt.colorbar()
plt.show()

# %% [markdown]
# Имеется ряд alias-ов для упрощения, например:
# - volume_x_slices - объемный разрез плоскостями, параллельными плоскости YZ.
# - get_z_slice - автоматический разрез плоскостью, параллельной плоскости XY.

# %%
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.tec') as ses:
    Y,Z,P_tot = ses.get_x_slice(cord = 0, values = ('Y', 'Z', 'P_tot'))
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.tec

# %%
xi, yi = np.meshgrid(
    np.linspace(Z.min(), Z.max(), 1000),
    np.linspace(Y.min(), Y.max(), 1000),             
)
zi = griddata(Z, Y, P_tot,xi, yi, interp='linear')
# Out:
# C:\Users\ewe\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
#
# The griddata function was deprecated in version 2.2.

# %%
fig = plt.figure(figsize = (15,10))
plt.imshow(zi, cmap = 'gist_rainbow')
plt.colorbar(orientation = 'horizontal')
plt.gca().set_aspect(1/5)
plt.tick_params(labelsize = 18)
plt.show()

# %% [markdown]
# Поверхностный срез имеет ту же сигнатуру, что и объемный, применяется для 2D моделей.

# %%
with wrap('2dkepsnotur.dtf') as ses:
    X,Y, W, P_tot = ses.surface_slices(
        origins = [
        (0,0,z) for z in [0, 0.33 -1e-14, 0.66-1e-14, 1-1e-14]
    ], 
        normal = (0,0,1),
        values = ('X', 'Y', 'W', 'P_tot'),
    )
# Out:
# C:\Users\Nanopro\tecwrap_guide\3dkepsnotur.dtf
# 0

# %% [markdown]
# Имеется функция для снятия данных по линии (задается пересечением двух плоскостей):

# %%
Z = [0, 0.33 -1e-14, 0.66-1e-14, 1-1e-14]
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.tec') as ses:
    Y, W = ses.surfaces_intersection(
        surface_1=[(0,0,0), (1,0,0)],
        surfaces = [
            [(0,0,z), (0,0,1)] for z in Z
        ],
        values = ('Y', 'W')
    )
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.tec

# %%
plt.figure(figsize = (15,10))
for y,w,z in zip(Y,W,Z): 
    umaxavg = w.max()/w.mean()
    plt.plot(np.sort(y),w[y.argsort()], label = r'Сечение '+ f'$z = {z:.4g}$'+  r', $\frac{W_{max}}{\overline{W}} ='+'{:.4g}'.format(umaxavg)+'$' )
    plt.title(f'Сравнение профилей скорости в различных сечениях', fontdict = {'fontsize': 18})
    plt.tick_params(labelsize = 18)
    plt.xlabel('$y, м$', fontdict = {'fontsize': 18})
    plt.ylabel('$W, м/с$', fontdict = {'fontsize': 18})
    plt.grid(True)
    plt.legend(fontsize = 18)

# %%
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.tec') as ses:
    Z, W = ses.surface_intersection(
        origins = [(0,0,0), (0,0,0)],
        normals = [(1,0,0), (0,1,0)],
        values = ('Z', 'W')
    )
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.tec

# %%
plt.figure(figsize = (15,10))
plt.plot(Z,W)
plt.title('Скорость на оси по длине', fontdict = {'fontsize': 18})
plt.tick_params(labelsize = 18)
plt.xlabel('$z, м$', fontdict = {'fontsize': 18})
plt.ylabel('$W, м/с$', fontdict = {'fontsize': 18})
plt.grid(True)

# %% [markdown]
# Также имеется возможность изъять все значения из всех активных зон:

# %%
with wrap('C:/users/ewe/tecwrap_guide/3dkepsnotur.tec') as ses:
    X, Y, Z = ses.get_values(values = ('X', 'Y', 'Z'))
# Out:
# C:/users/ewe/tecwrap_guide/3dkepsnotur.tec

# %%
Z
# Out:
# array([[0.   , 0.005, 0.01 , ..., 0.99 , 0.995, 1.   ]])

# %% [markdown]
# # Использование pytecplot напрямую.

# %% [markdown]
# Я использовал библиотеку pytecplot следующим образом:

# %% [markdown]
# - Импорты:

# %%
import tecplot as tp, tecplot
import numpy as np
import os
import subprocess
import functools
import psutil

# %% [markdown]
# Запускаем TecPlot360 руками, после запуска ставим галочку в:

# %% [markdown]
# <img src = "images/con1.png">
# <img src = "images/con2.png">

# %% [markdown]
# Устанавливаем соединение:

# %%
tp.session.connect(timeout=20)
# Out:
# Connecting to Tecplot 360 TecUtil Server on:
#     tcp://localhost:7600
# Connection established.

# %% [markdown]
# Если соединение установлено успешно, выведется сообщение: Connection established.

# %% [markdown]
# Открываем нужный файл, руками в TecPlot, либо следующей строкой (результат выполнения сохраняем в переменную dataset):

# %%
dataset = tp.data.load_tecplot('C:/users/ewe/tecwrap_guide/3dkepsnotur.tec', read_data_option=tp.constant.ReadDataOption.ReplaceInActiveFrame)

# %% [markdown]
# ------------------------------
# ### Опционально:
#
#
# Для того чтобы экспортировать файл из формата .dtf в формат .tec, можно воспользоваться следующей командой:

# %%
file = 'C:/users/ewe/tecwrap_guide/3dkepsnotur.dtf'
os.system(r'dtf_to_tec.exe {input} {out} 1'.format(input=file, out=file[:-3] + 'tec'))
# Out:
# 0

# %% [markdown]
# В случае успеха, мы получим код 0.
#
#
# ---------------------------------------------------

# %% [markdown]
# Для того чтобы работать с 2D геометрией как с 3D, создадим новую переменную Z_NULL равной 0, синтаксис совпадаем с equations в самом TecPlot:

# %%
tp.data.operate.execute_equation(equation='{Z_NULL}=0')

# %% [markdown]
# Для того чтобы изменить тип графика в активном окне, сохраним ссылку на график, и изменимим его аттребут:

# %%
frame = tp.active_frame()
frame.plot_type = tp.constant.PlotType.Cartesian3D

# %% [markdown]
# Задать какие переменные будут использоваться в качестве осей для графика, можно следующим образом:

# %%
frame.plot().axes.z_axis.variable = self.dataset.variable('Z_NULL')

# %% [markdown]
# Для того чтобы извлечь данные слайсом:

# %%
extracted_slice = tp.data.extract.extract_slice(
            origin=(0,0,1), #точка
            normal=(0,0,0.5-1e-14), #нормаль
            source=tp.constant.SliceSource.VolumeZones, #тип слайса
            dataset=dataset) #датасет

# %% [markdown]
# Для того чтобы извлечь нужные переменные и сохранить их в np.array:

# %%
P = extracted_slice.values('P_tot').as_numpy_array()

# %%
P
# Out:
# array([120136.85156233, 120923.99999965, 121359.70312422, 121652.74999917,
#        121652.74999917, 120136.85156265, 121359.70312461, 120136.8515625 ,
#        120136.85156233, 120136.85156233, 120136.8515625 , 120136.85156265,
#        120924.        , 121141.8515625 , 121359.703125  , 121723.11979167,
#        121652.75      , 121751.171875  , 121652.75000054, 121652.75000013,
#        121652.75      , 122140.35625   , 121359.703125  , 121359.70312524,
#        120924.        , 120136.8515625 , 120136.85156265, 122661.71093732,
#        122395.40885417, 121359.70312524, 121359.703125  , 121359.70312461,
#        121555.06770833, 122461.984375  , 122351.1796875 , 122661.7109375 ,
#        122661.71093759, 122661.71093759, 122661.7109375 , 122661.71093732,
#        122120.2421875 , 122440.1015625 , 122440.1015625 , 122859.3359375 ,
#        122962.80078125, 123066.265625  , 122928.3125    , 123066.265625  ,
#        122859.3359375 , 122859.33593731, 122859.3359375 , 122440.1015625 ,
#        121726.56640625, 122579.84635417, 122859.3359375 , 123066.265625  ,
#        123066.26562491, 123066.265625  , 123066.26562491, 122983.49375   ,
#        122440.10156269, 122661.71093759, 122440.1015625 , 122120.2421875 ,
#        122368.9640625 , 121652.74999959, 121652.75      , 121957.50390625,
#        122461.984375  , 122083.54296875, 122661.7109375 , 122661.71093759,
#        122740.7609375 , 122661.7109375 , 122501.9296875 , 122395.40885417,
#        121359.70312422, 120136.85156265, 121359.703125  , 121904.828125  ,
#        121904.82812476, 122262.2578125 , 122262.25781266, 122226.86197917,
#        122175.18526786, 120136.85156265, 120136.8515625 , 120136.85156233,
#        120924.        , 120924.00000019, 120399.234375  , 121652.74999961,
#        121652.75      , 121779.29241071, 121800.3828125 , 121800.3828125 ,
#        121800.38281207, 121652.75      , 121401.56696429, 120136.85156285,
#        120136.8515625 , 120136.85156233, 120562.375     , 120721.1875    ,
#        120721.18750005, 120721.18750005, 120721.1875    , 120562.375     ,
#        111396.26822917, 106071.14843746, 111534.60156171, 109877.47656244,
#        111534.6015625 , 112578.54947917, 113152.60677083, 114680.671875  ,
#        117675.29947917, 119223.65364583, 120562.375     , 106071.1484375 ,
#        106071.14843813, 109877.47656144, 107537.25781248, 109877.4765625 ,
#        109919.89322917, 111675.5859375 , 113256.7734375 , 114766.6171875 ,
#        115772.04427083, 116786.7890625 , 117810.8515625 , 119367.4921875 ,
#        119367.49218764, 120721.1875    , 120721.18750005, 106115.6015625 ,
#        107537.2578125 , 109139.8203125 , 110543.05989583, 109941.1015625 ,
#        111746.9765625 , 113335.6875    , 114853.203125  , 114853.20312567,
#        117913.03906181, 117913.0390625 , 117913.03906319, 117913.0390625 ,
#        106115.6015625 , 107537.2578125 , 109941.1015625 , 109941.10156247,
#        111746.9765625 , 113335.6875    , 113335.68749996, 114853.203125  ,
#        116086.8515625 , 115900.57552083, 114594.7265625 , 114492.5015625 ,
#        113100.5234375 , 112984.7890625 , 111534.6015625 , 111368.6015625 ,
#        109752.09375   , 109605.825     , 107382.7890625 , 107255.6640625 ,
#        105983.609375  , 105882.428125  , 120136.8515625 , 120136.85156233,
#        118833.8125    , 118833.81249932, 118833.81249992, 117306.22656242,
#        120136.85156233, 107283.9140625 , 111396.26822917, 117306.22656183,
#        117306.2265625 , 118324.6171875 , 117507.09114583, 119268.15885417,
#        120136.8515625 , 120136.85156265, 107382.78906188, 107382.7890625 ,
#        107382.78906355, 107434.0078125 , 111534.60156171, 111534.6015625 ,
#        112317.5625    , 111605.09375   , 119367.4921874 , 107511.2421875 ,
#        116369.22656246, 119367.49218681, 117913.03906245, 119367.4921875 ,
#        119367.4921881 , 119403.6796875 , 107537.25781187, 107537.2578125 ,
#        109139.8203125 , 107537.2578125 , 115611.21484375, 116369.2265625 ,
#        117913.0390625 , 118434.04427083, 117913.0390625 , 107485.22656252,
#        115762.8171875 , 116369.2265625 , 116369.22656319, 116321.9921875 ,
#        107485.22656187, 107485.2265625 , 107485.22656356, 107416.93489583,
#        116180.8046875 , 105857.13281256, 107333.3515625 , 111465.43489583,
#        113023.3671875 , 115340.7890625 , 114466.9453125 , 116086.8515625 ,
#        117100.6328125 , 116086.85156238, 118992.7734375 , 120136.85156265,
#        105857.1328125 , 105857.13281247, 107234.4765625 , 107234.47656354,
#        107234.47656246, 111327.10156172, 111327.1015625 , 111327.10156245,
#        112869.0546875 , 112869.05468744, 114339.1640625 , 114339.16406315,
#        114339.16406243, 118833.81249932, 118833.8125    , 118833.81249992,
#        120136.8515625 , 120136.85156233])

# %% [markdown]
# Получить список переменных:

# %%
[var.name for var in dataset.variables()]
# Out:
# ['X',
#  'Y',
#  'Z',
#  'RHO',
#  'U',
#  'V',
#  'W',
#  'VelocityMagnitude',
#  'Mach',
#  'P',
#  'P_tot',
#  'Vislam',
#  'T',
#  'T_TOT',
#  'H0',
#  'COND_TURB',
#  'CP',
#  'COND_eff',
#  'D',
#  'K']

# %% [markdown]
# Список активных зон:

# %%
[var.name for var in frame.active_zones()]
# Out:
# ['Simple zone 1',
#  'Simple zone 2',
#  'Simple zone 3',
#  'Simple zone 4',
#  'Simple zone 5',
#  'Slice: Z=1']

# %% [markdown]
# Изменить список активных зон:

# %%
frame.active_zones([frame.active_zones()[-1]])
# Out:
# ([Zone(uid=165, dataset=Dataset(uid=136, frame=Frame(uid=2, page=Page(uid=1))))],)

# %% [markdown]
# Активировать все зоны:

# %%
frame.active_zones(dataset.zones())
# Out:
# (<generator object Dataset.zones at 0x0000006FD35C2888>,)

# %% [markdown]
# Также можно напрямую исполнять макросы:

# %%
tp.macro.execute_extended_command(command_processor_id='CFDAnalyzer4',
    command="""SetFluidProperties 
    Incompressible='F' 
    Density=1 
    SpecificHeat=2.5 
    UseSpecificHeatVar='F' 
    SpecificHeatVar=1 
    GasConstant=287
    UseGasConstantVar='F' 
    GasConstantVar=1 
    Gamma=1.41 
    UseGammaVar='F' 
    GammaVar=1 
    Viscosity=1 
    UseViscosityVar='F' 
    ViscosityVar=1 
    Conductivity=1 
    UseConductivityVar='F' 
    ConductivityVar=1
    """)
